# %%
import pandas as pd

# %%
HDW= pd.read_excel("Data\Excels\ATT HDWE CT.xlsx", sheet_name="Design 1")
HDW
# Out:
#         ID   FMSI SHORT FMSI                  Category Hardware_REF  \
# 0        1  D0002         D2                       TBD       ATT039
# 1        1  D0002         D2  Other Attaching Hardware      XLD4156
# 2        1  D0002         D2               Wear Sensor       SEN126
# 3        1  D0002         D2            Wear Sensor v1       SEN151
# 4        1  D0002         D2            Wear Sensor v2       SEN299
# ...    ...    ...        ...                       ...          ...
# 2676  1447  D0723       D723               Wear Sensor       SEN192
# 2677  1448  D0828       D828               Wear Sensor       SEN192
# 2678  1449  D0884       D884               Wear Sensor       SEN192
# 2679  1450  D1338      D1338               Wear Sensor    XLD2325-3
# 2680  1450  D1338      D1338            Wear Sensor v1    XLD2626-5
#
#                                  New Category
# 0                                         TBD
# 1                                         TBD
# ...

# %%
categories= set(HDW['New Category'])

# %%
with pd.ExcelWriter("Data\Excels\Database_HDW.xlsx") as writer:
    for category in categories:
        DF= HDW[HDW['New Category']==category]
        DF["Attribute 1"]= None
        DF["Attribute 2"]= None
        DF["Attribute 3"]= None
        DF.to_excel(writer, sheet_name=category, index=False)
# Out:
# C:\Users\AHMED Raja\AppData\Local\Temp\ipykernel_24796\473089123.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF["Attribute 1"]= None
# C:\Users\AHMED Raja\AppData\Local\Temp\ipykernel_24796\473089123.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF["Attribute 2"]= None
# C:\Users\AHMED Raja\AppData\Local\Temp\ipykernel_24796\473089123.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
